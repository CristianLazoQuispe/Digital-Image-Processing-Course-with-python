# %% [markdown]
# # Importar librerias

# %%
import matplotlib.pyplot as plt
import cv2

import numpy as np

# %matplotlib inline  

plt.rcParams['figure.figsize'] = [10,5]

# %% [markdown]
# # Leer una imagen

# %%
imgbgr = cv2.imread('arcoiris.jpg')
# OPENCV     LEE LAS IMAGENES EN BGR
# MATPLOTLIB LEE LAS IMAGENES EN RGB

print('Tamaño :',imgbgr.shape)
# Out:
# Tamaño : (531, 800, 3)

# %%
#plt.imshow(imgbgr)
#plt.show()

# %%
imgbgr = cv2.imread('/home/cristian/Pictures/miraflores2.png')
print('Tamaño :',imgbgr.shape)
# Out:
# Tamaño : (768, 1366, 3)

# %%
# Ploteando imagen con matplotlib
# CAMBIOS DE COLOR
imgrgb = cv2.cvtColor(imgbgr, cv2.COLOR_BGR2RGB)
#imgrgb = cv2.cvtColor(imgbgr,cv2.COLOR_BGR2HSV)

plt.imshow(imgrgb)
plt.show()

# %%
# Ploteando los 3 canales
# IMGRGB 

plt.figure() # CREA EL ESPACIO DE UNA IMAGEN

plt.subplot(131)
plt.imshow(imgrgb[:,:,0],cmap='gray')
plt.title('R channel')
plt.subplot(132)
plt.imshow(imgrgb[:,:,1],cmap='gray')
plt.title('G channel')
plt.subplot(133)
plt.imshow(imgrgb[:,:,2],cmap='gray')
plt.title('B channel')

plt.show()  # MUESTRA LA IMAGEN DE LA FIGURA

# %%
img_BGR = cv2.imread('arcoiris.jpg')
print(img_BGR.shape)

plt.imshow(cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB))
plt.show()
img_RGB = plt.imread('arcoiris.jpg')
print(img_RGB.shape)
plt.imshow(img_RGB)
plt.show()
# Out:
# (531, 800, 3)
# (531, 800, 3)

# %%
imghsv = cv2.cvtColor(imgbgr,cv2.COLOR_BGR2HSV)

# %%
h_channel = imghsv[:,:,0]

# %%
h_channel.max()
# Out:
# 179

# %%
import cv2

img = cv2.imread('arcoiris.jpg')

B_1,G_1,R_1= cv2.split(img)

B_2 = img[:,:,0]
G_2 = img[:,:,1]
R_2 = img[:,:,2]

# %%
print(B_1.shape)
print(B_2.shape)
# Out:
# (531, 800)
# (531, 800)

# %%
import matplotlib.pyplot as plt
import cv2

img_BGR = cv2.imread('arcoiris.jpg')

# %%
cv2.imwrite('arcoiris_cv2.png',img_BGR)

plt.imsave('arcoiris_plt.png',cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB))
